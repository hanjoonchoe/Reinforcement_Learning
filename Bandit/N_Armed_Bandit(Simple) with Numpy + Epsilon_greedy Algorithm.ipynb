# %%
import numpy as np

# %%
class Bandit(object):
    
    def __init__(self,n_armed,n_episodes,epsilon):
        
        self.n_armed = n_armed
        self.epsilon = epsilon
        self.n_episodes = n_episodes
        self.reward = 0
        self.choice = 0
        self.best_arm = np.random.rand(1,self.n_armed)
        self.total_reward = np.zeros((1,self.n_armed))
        self.total_count = np.zeros((1,self.n_armed))
        
    def pullBandit(self,i):
        
        if np.random.rand(1)<self.best_arm[0][i]:
            return 1
        else:
            return 0
        
    def EpsilonGreedy(self):
        
        if abs(np.random.randn(1))<self.epsilon:
            
            self.choice = np.argmax(np.random.randn(1,self.n_armed))
            self.total_count[0][self.choice] += 1
            self.reward = self.pullBandit(self.choice)
            self.total_reward[0][self.choice] += 1/self.total_count[0][self.choice]*(self.reward - self.total_reward[0][self.choice])
            
            return self.total_reward
            
        else:
            self.choice = np.argmax(self.total_reward[0])
            self.total_count[0][self.choice] += 1
            self.reward = self.pullBandit(self.choice)
            self.total_reward[0][self.choice] += 1/self.total_count[0][self.choice]*(self.reward - self.total_reward[0][self.choice])
            
            return self.total_reward
        
    def Main(self):
        
        i = 0
        while i<self.n_episodes:
            self.total_reward = self.EpsilonGreedy()
            i+=1
        print('Finish')
        if np.argmax(self.total_reward) == np.argmax(self.best_arm):
            print("Result : Correct")
        else:
            print("Result : False")
        return self.total_reward, self.best_arm

# %%
for _ in range(100):
    _,_ = Bandit(n_armed=4,n_episodes=1000,epsilon=.1).Main()
# Out:
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : False
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : False
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : False
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : False
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : False
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : False
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
# Finish
# Result : Correct
